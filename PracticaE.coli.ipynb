# %%
Una cepa de E.coli tiene una taza de crecimiento tal que un individuo se duplica cada 30 minutos. Calcula en cuanto tiempo esta capa:
a) Llenaría el volumen de la Tierra
b) Cubriría la superficie de la Tierra
c) Repite el calculo para una taza de crecimiento
   i) Se duplica cada hora
   ii) Se duplica cada 1/4 de hora
DATOS
rT= 6,371km
rE= 0.5nm

# %%
import math as mt

# %%
a) Volumen de la Tierra

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**3/rE**3
print (N)
# Out:
# 2.0687728224879996e+39

# %%
b) Superficie de la Tierra

# %%
N= rT**3/rE**3
t= mt.log2(N)
print(t)
# Out:
# 130.6039709282774

# %%
t=mt.log2(N)
th=t/2
td=th/24
print(td)
# Out:
# 2.720916061005779
