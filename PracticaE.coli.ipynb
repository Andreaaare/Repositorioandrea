# %% [markdown]
# ***Una cepa de E.coli tiene una taza de crecimiento tal que un individuo se duplica cada 30 minutos.***
#
# Calcula en cuanto tiempo esta cepa:
#
# a) Llenaría el volumen de la Tierra
#
# b) Cubriría la superficie de la Tierra
#
# c) Repite el calculo para una taza de crecimiento
#
#    i) Se duplica cada hora
#
#    ii) Se duplica cada 1/4 de hora
#
# *DATOS*
#
# rT= 6,371km
#
# rE= 0.5nm

# %%
import math as mt

# %% [markdown]
# **a) Volumen de la Tierra**

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**3/rE**3
print (N)
# Out:
# 2.0687728224879996e+39

# %%
N= rT**3/rE**3
t= mt.log2(N)
print(t)
# Out:
# 130.6039709282774

# %%
t=mt.log2(N)
th=t/2
td=th/24
print(td)
# Out:
# 2.720916061005779

# %% [markdown]
# **b) Superficie de la Tierra**

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**2/rE**2
print(N)
# Out:
# 1.6235856399999996e+26

# %%
N= rT**2/rE**2
t= mt.log2(N)
print(t)
# Out:
# 87.06931395218493

# %%
t=mt.log2(N)
th=t/2
td=th/24
print(td)
# Out:
# 1.8139440406705194

# %% [markdown]
# **c) Tasas de cremiento**

# %% [markdown]
# *i) Tasa de crecimiento: 1 hora*

# %% [markdown]
# *Volumen*

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**3/rE**3
print(N)
# Out:
# 2.0687728224879996e+39

# %%
N= rT**3/rE**3
t= mt.log2(N)
print(t)
# Out:
# 130.6039709282774

# %%
t=mt.log2(N)
th= t
td=th/24
print(td)
# Out:
# 5.441832122011558

# %% [markdown]
# *Superficie*

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**2/rE**2
print(N)
# Out:
# 1.6235856399999996e+26

# %%
N= rT**2/rE**2
t= mt.log2(N)
print(t)
# Out:
# 87.06931395218493

# %%
t=mt.log2(N)
th=t 
td=th/24
print(td)
# Out:
# 3.627888081341039

# %% [markdown]
# *ii) Tasa de crecimiento: 1/4 de hora*

# %% [markdown]
# *Volumen*

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**3/rE**3
print(N)
# Out:
# 2.0687728224879996e+39

# %%
N= rT**3/rE**3
t= mt.log2(N)
print(t)
# Out:
# 130.6039709282774

# %%
t=mt.log2(N)
th=t/4
td=th/24
print(td)
# Out:
# 1.3604580305028895

# %% [markdown]
# *Superficie*

# %%
rT= 6372*10e3
rE= 0.5*10e-6
N= rT**2/rE**2
print(N)
# Out:
# 1.6240953599999997e+26

# %%
N= rT**2/rE**2
t= mt.log2(N)
print(t)
# Out:
# 87.06976681102314

# %%
t=mt.log2(N)
th=t/4
td=th/24
print(td)
# Out:
# 0.9069767376148244
