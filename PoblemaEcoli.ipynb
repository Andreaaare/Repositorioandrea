# %%
Una capa de E.coli tiene una taza de creciemiento tal que un individuo se duplica cada 30 minutos. Calcula en cuanto tiempo esta capa

a) Llenaria el Volumen de la Tierra
b) Cubriría la superficie de la Tierra
c) Repite el calculo para una taza de crecimiento
   i) Se duplica cada hora
   ii) Se duplica cada 1/4 de hora
Datos  
rt= 6,371km
rE= o.5nm
# Out:
#   Cell In[10], line 3
#     a) Llenaria el Volumen de la Tierra
#      ^
# SyntaxError: unmatched ')'

# %%
import math as mt

# %%
Superficie de la Tierra

# %%
rT= 6371*10e3 
rE= 0.5*10e-6 
N= rT**3/rE**3
print(N)
# Out:
# 2.0687728224879996e+39

# %%
Tasa de crecimiento (t)

# %%
N= rT**3/rE**3
t= mt.log2(N)
print(t)
# Out:
# 130.6039709282774

# %%
t=mt.log2(N)
th=t/2
td=th/24
print(td)
# Out:
# 2.720916061005779
